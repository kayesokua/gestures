# %% [markdown]
# # Data Collection and Annotation
#
# https://developers.google.com/youtube/v3/docs/search/list
#
# ## Import Modules

# %%
import warnings
warnings.filterwarnings("ignore", message="^objc")

from src.data.collection import extract_video_from_youtube
from src.data.annotation import extract_landmarks, extract_frames

# %% [markdown]
# ## Youtube Search Parameters

# %%
extract_video_from_youtube(
    query='contemporary+dance+solo+choreography',
    count=5,
    output_dir='data/external')
# Out:
# 0/5 Downloaded
# 1/5 Downloaded
# 2/5 Downloaded
# 3/5 Downloaded
# 4/5 Downloaded
# Downloaded 5 videos
# Elapsed time: 35.236 seconds

# %% [markdown]
# ## Pose Detection using MediaPipe
#
# For our preliminary analysis, we will use one clean video
#
# https://developers.google.com/mediapipe/solutions/examples

# %%
extract_landmarks(
    input_video='./data/external/contemporary_dance_solo_choreography_20230410163051_2.mp4',
    output_csv='./data/interim/landmarks/contemporary_dance_solo_choreography_20230410163051_2.csv'
)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# No pose detected in frame 0
# No pose detected in frame 1
# No pose detected in frame 2
# No pose detected in frame 3
# No pose detected in frame 4
# No pose detected in frame 5
# No pose detected in frame 6
# No pose detected in frame 7
# No pose detected in frame 8
# No pose detected in frame 9
# No pose detected in frame 10
# No pose detected in frame 11
# No pose detected in frame 12
# No pose detected in frame 13
# No pose detected in frame 14
# No pose detected in frame 15
# No pose detected in frame 16
# No pose detected in frame 17
# No pose detected in frame 18
# No pose detected in frame 19
# No pose detected in frame 20
# No pose detected in frame 21
# No pose detected in frame 22
# No pose detected in frame 23
# No pose detected in frame 24
# No pose detected in frame 25
# No pose detected in frame 26
# No pose detected in frame 29
# No pose detected in frame 30
# No pose detected in frame 32
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/interim/landmarks/contemporary_dance_solo_choreography_20230410163051_2.csv')
df.describe()
# Out:
#              frame  landmarks       nose_x       nose_y       nose_z  \
# count  5436.000000        0.0  3308.000000  3308.000000  3308.000000
# mean   2717.500000        NaN     0.527859     0.418453    -0.069438
# std    1569.382363        NaN     0.100580     0.120612     0.131835
# min       0.000000        NaN     0.000073     0.190068    -0.811820
# 25%    1358.750000        NaN     0.478618     0.348384    -0.147600
# 50%    2717.500000        NaN     0.521541     0.397202    -0.074281
# 75%    4076.250000        NaN     0.569448     0.447481     0.012874
# max    5435.000000        NaN     0.964416     0.971922     0.517326
#
#        left_eye_inner_x  left_eye_inner_y  left_eye_inner_z   left_eye_x  \
# count       3308.000000       3308.000000       3308.000000  3308.000000
# mean           0.529364          0.408379         -0.068890     0.530256
# std            0.100527          0.124133          0.125251     0.100443
# ...
